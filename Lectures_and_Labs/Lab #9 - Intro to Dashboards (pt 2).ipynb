# %% [markdown]
# # Dashboards using Streamlit
#
#
# Some useful Streamlit comands:
#
# * st.table() to visualize a table
# * st.text_input() for search boxes
# * st.slider() for numeric filters
# * st.selectbox() for dropdown lists
# * st.multiselect() for multiple-choice filters
# * st.metric() for single-value KPIs
# * Using st.columns() for side-by-side metrics
# * Buttons: st.button()
# * Toggles: st.checkbox()
# * Radio buttons: st.radio()
# * Date pickers: st.date_input()
# * File uploads: st.file_uploader()
# * Using st.bar_chart(), st.line_chart(), and st.area_chart()
# * Using st.sidebar() for navigation and filters
# * Using st.expander() for collapsible sections
# * Organizing with st.container()
# * st.image() to display an image (e.g., PNG, JPG).

# %%
import pandas as pd
import numpy as np
# %pip install streamlit
import streamlit as st
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: streamlit in C:\Users\Ksing\AppData\Roaming\Python\Python314\site-packages (1.58.0)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<7,>=4.0 in C:\Users\Ksing\AppData\Roaming\Python\Python314\site-packages (from streamlit) (6.2.1)
# Requirement already satisfied: blinker<2,>=1.5.0 in C:\Users\Ksing\AppData\Roaming\Python\Python314\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<8,>=5.5 in C:\Users\Ksing\AppData\Roaming\Python\Python314\site-packages (from streamlit) (7.1.4)
# Requirement already satisfied: click<9,>=7.0 in C:\Users\Ksing\AppData\Roaming\Python\Python314\site-packages (from streamlit) (8.4.1)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in C:\Users\Ksing\AppData\Roaming\Python\Python314\site-packages (from streamlit) (3.1.50)
# Requirement already satisfied: numpy<3,>=1.23 in C:\Users\Ksing\AppData\Roaming\Python\Python314\site-packages (from streamlit) (2.4.6)
# Requirement already satisfied: packaging>=20 in C:\Users\Ksing\AppData\Roaming\Python\Python314\site-packages (from streamlit) (26.2)
# Requirement already satisfied: pandas<4,>=1.4.0 in C:\Users\Ksing\AppData\Roaming\Python\Python314\site-packages (from streamlit) (3.0.3)
# Requirement already satisfied: pillow<13,>=7.1.0 in C:\Users\Ksing\AppData\Roaming\Python\Python314\site-packages (from streamlit) (12.2.0)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in C:\Users\Ksing\AppData\Roaming\Python\Python314\site-packages (from streamlit) (0.9.2)
# Requirement already satisfied: protobuf<8,>=3.20 in C:\Users\Ksing\AppData\Roaming\Python\Python314\site-packages (from streamlit) (7.35.0)
# Requirement already satisfied: pyarrow>=7.0 in C:\Users\Ksing\AppData\Roaming\Python\Python314\site-packages (from streamlit) (24.0.0)
# Requirement already satisfied: requests<3,>=2.27 in C:\Users\Ksing\AppData\Roaming\Python\Python314\site-packages (from streamlit) (2.34.2)
# Requirement already satisfied: tenacity<10,>=8.1.0 in C:\Users\Ksing\AppData\Roaming\Python\Python314\site-packages (from streamlit) (9.1.4)
# Requirement already satisfied: toml<2,>=0.10.1 in C:\Users\Ksing\AppData\Roaming\Python\Python314\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.10.0 in c:\Program Files\Python314\Lib\site-packages (from streamlit) (4.15.0)
# Requirement already satisfied: starlette>=0.40.0 in C:\Users\Ksing\AppData\Roaming\Python\Python314\site-packages (from streamlit) (1.3.1)
# Requirement already satisfied: uvicorn>=0.30.0 in C:\Users\Ksing\AppData\Roaming\Python\Python314\site-packages (from streamlit) (0.49.0)
# Requirement already satisfied: httptools>=0.6.3 in C:\Users\Ksing\AppData\Roaming\Python\Python314\site-packages (from streamlit) (0.8.0)
# Requirement already satisfied: anyio>=4.0.0 in c:\Program Files\Python314\Lib\site-packages (from streamlit) (4.14.0)
# Requirement already satisfied: python-multipart>=0.0.10 in C:\Users\Ksing\AppData\Roaming\Python\Python314\site-packages (from streamlit) (0.0.32)
# Requirement already satisfied: websockets>=12.0.0 in C:\Users\Ksing\AppData\Roaming\Python\Python314\site-packages (from streamlit) (16.0)
# Requirement already satisfied: itsdangerous>=2.1.2 in C:\Users\Ksing\AppData\Roaming\Python\Python314\site-packages (from streamlit) (2.2.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in C:\Users\Ksing\AppData\Roaming\Python\Python314\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: jinja2 in c:\Program Files\Python314\Lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in C:\Users\Ksing\AppData\Roaming\Python\Python314\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (4.26.0)
# Requirement already satisfied: narwhals>=2.4.0 in C:\Users\Ksing\AppData\Roaming\Python\Python314\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2.22.1)
# Requirement already satisfied: colorama in C:\Users\Ksing\AppData\Roaming\Python\Python314\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in C:\Users\Ksing\AppData\Roaming\Python\Python314\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in C:\Users\Ksing\AppData\Roaming\Python\Python314\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\Ksing\AppData\Roaming\Python\Python314\site-packages (from pandas<4,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\Ksing\AppData\Roaming\Python\Python314\site-packages (from pandas<4,>=1.4.0->streamlit) (2026.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\Ksing\AppData\Roaming\Python\Python314\site-packages (from requests<3,>=2.27->streamlit) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\Ksing\AppData\Roaming\Python\Python314\site-packages (from requests<3,>=2.27->streamlit) (3.17)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\Ksing\AppData\Roaming\Python\Python314\site-packages (from requests<3,>=2.27->streamlit) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in C:\Users\Ksing\AppData\Roaming\Python\Python314\site-packages (from requests<3,>=2.27->streamlit) (2026.5.20)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\Program Files\Python314\Lib\site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in C:\Users\Ksing\AppData\Roaming\Python\Python314\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in C:\Users\Ksing\AppData\Roaming\Python\Python314\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in C:\Users\Ksing\AppData\Roaming\Python\Python314\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in C:\Users\Ksing\AppData\Roaming\Python\Python314\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2026.5.1)
# Requirement already satisfied: six>=1.5 in C:\Users\Ksing\AppData\Roaming\Python\Python314\site-packages (from python-dateutil>=2.8.2->pandas<4,>=1.4.0->streamlit) (1.17.0)
# Requirement already satisfied: h11>=0.8 in c:\Program Files\Python314\Lib\site-packages (from uvicorn>=0.30.0->streamlit) (0.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
#import streamlit as st
import pandas as pd
import numpy as np
# %pip install streamlit
import streamlit as st
# Sample Data
data = {
    'Order ID': range(1, 21),
    'Product': ['Laptop', 'Phone', 'Tablet', 'Monitor', 'Headphones'] * 4,
    'Category': ['Electronics', 'Electronics', 'Electronics', 'Accessories', 'Accessories'] * 4,
    'Price': np.random.randint(50, 1000, 20),
    'Quantity': np.random.randint(1, 5, 20)
}
df = pd.DataFrame(data)
df['Total'] = df['Price'] * df['Quantity']

# Sidebar Filter
st.sidebar.header("Filters")
category_filter = st.sidebar.selectbox("Select Category", ['All'] + list(df['Category'].unique()))
if category_filter != 'All':
    df = df[df['Category'] == category_filter]

# KPIs
st.title("E-commerce Sales Dashboard")
st.metric("Total Revenue", f"${df['Total'].sum():,.2f}")
st.metric("Total Orders", len(df))

# Data Table
st.subheader("Sales Data")
st.dataframe(df)

# Chart
st.subheader("Sales by Category")
category_sales = df.groupby('Category')['Total'].sum().reset_index()
st.bar_chart(category_sales.set_index('Category'))
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: streamlit in C:\Users\Ksing\AppData\Roaming\Python\Python314\site-packages (1.58.0)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<7,>=4.0 in C:\Users\Ksing\AppData\Roaming\Python\Python314\site-packages (from streamlit) (6.2.1)
# Requirement already satisfied: blinker<2,>=1.5.0 in C:\Users\Ksing\AppData\Roaming\Python\Python314\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<8,>=5.5 in C:\Users\Ksing\AppData\Roaming\Python\Python314\site-packages (from streamlit) (7.1.4)
# Requirement already satisfied: click<9,>=7.0 in C:\Users\Ksing\AppData\Roaming\Python\Python314\site-packages (from streamlit) (8.4.1)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in C:\Users\Ksing\AppData\Roaming\Python\Python314\site-packages (from streamlit) (3.1.50)
# Requirement already satisfied: numpy<3,>=1.23 in C:\Users\Ksing\AppData\Roaming\Python\Python314\site-packages (from streamlit) (2.4.6)
# Requirement already satisfied: packaging>=20 in C:\Users\Ksing\AppData\Roaming\Python\Python314\site-packages (from streamlit) (26.2)
# Requirement already satisfied: pandas<4,>=1.4.0 in C:\Users\Ksing\AppData\Roaming\Python\Python314\site-packages (from streamlit) (3.0.3)
# Requirement already satisfied: pillow<13,>=7.1.0 in C:\Users\Ksing\AppData\Roaming\Python\Python314\site-packages (from streamlit) (12.2.0)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in C:\Users\Ksing\AppData\Roaming\Python\Python314\site-packages (from streamlit) (0.9.2)
# Requirement already satisfied: protobuf<8,>=3.20 in C:\Users\Ksing\AppData\Roaming\Python\Python314\site-packages (from streamlit) (7.35.0)
# Requirement already satisfied: pyarrow>=7.0 in C:\Users\Ksing\AppData\Roaming\Python\Python314\site-packages (from streamlit) (24.0.0)
# Requirement already satisfied: requests<3,>=2.27 in C:\Users\Ksing\AppData\Roaming\Python\Python314\site-packages (from streamlit) (2.34.2)
# Requirement already satisfied: tenacity<10,>=8.1.0 in C:\Users\Ksing\AppData\Roaming\Python\Python314\site-packages (from streamlit) (9.1.4)
# Requirement already satisfied: toml<2,>=0.10.1 in C:\Users\Ksing\AppData\Roaming\Python\Python314\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.10.0 in c:\Program Files\Python314\Lib\site-packages (from streamlit) (4.15.0)
# Requirement already satisfied: starlette>=0.40.0 in C:\Users\Ksing\AppData\Roaming\Python\Python314\site-packages (from streamlit) (1.3.1)
# Requirement already satisfied: uvicorn>=0.30.0 in C:\Users\Ksing\AppData\Roaming\Python\Python314\site-packages (from streamlit) (0.49.0)
# Requirement already satisfied: httptools>=0.6.3 in C:\Users\Ksing\AppData\Roaming\Python\Python314\site-packages (from streamlit) (0.8.0)
# Requirement already satisfied: anyio>=4.0.0 in c:\Program Files\Python314\Lib\site-packages (from streamlit) (4.14.0)
# Requirement already satisfied: python-multipart>=0.0.10 in C:\Users\Ksing\AppData\Roaming\Python\Python314\site-packages (from streamlit) (0.0.32)
# Requirement already satisfied: websockets>=12.0.0 in C:\Users\Ksing\AppData\Roaming\Python\Python314\site-packages (from streamlit) (16.0)
# Requirement already satisfied: itsdangerous>=2.1.2 in C:\Users\Ksing\AppData\Roaming\Python\Python314\site-packages (from streamlit) (2.2.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in C:\Users\Ksing\AppData\Roaming\Python\Python314\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: jinja2 in c:\Program Files\Python314\Lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in C:\Users\Ksing\AppData\Roaming\Python\Python314\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (4.26.0)
# Requirement already satisfied: narwhals>=2.4.0 in C:\Users\Ksing\AppData\Roaming\Python\Python314\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2.22.1)
# Requirement already satisfied: colorama in C:\Users\Ksing\AppData\Roaming\Python\Python314\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in C:\Users\Ksing\AppData\Roaming\Python\Python314\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in C:\Users\Ksing\AppData\Roaming\Python\Python314\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\Ksing\AppData\Roaming\Python\Python314\site-packages (from pandas<4,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\Ksing\AppData\Roaming\Python\Python314\site-packages (from pandas<4,>=1.4.0->streamlit) (2026.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\Ksing\AppData\Roaming\Python\Python314\site-packages (from requests<3,>=2.27->streamlit) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\Ksing\AppData\Roaming\Python\Python314\site-packages (from requests<3,>=2.27->streamlit) (3.17)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\Ksing\AppData\Roaming\Python\Python314\site-packages (from requests<3,>=2.27->streamlit) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in C:\Users\Ksing\AppData\Roaming\Python\Python314\site-packages (from requests<3,>=2.27->streamlit) (2026.5.20)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\Program Files\Python314\Lib\site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in C:\Users\Ksing\AppData\Roaming\Python\Python314\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in C:\Users\Ksing\AppData\Roaming\Python\Python314\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in C:\Users\Ksing\AppData\Roaming\Python\Python314\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in C:\Users\Ksing\AppData\Roaming\Python\Python314\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2026.5.1)
# Requirement already satisfied: six>=1.5 in C:\Users\Ksing\AppData\Roaming\Python\Python314\site-packages (from python-dateutil>=2.8.2->pandas<4,>=1.4.0->streamlit) (1.17.0)
# Requirement already satisfied: h11>=0.8 in c:\Program Files\Python314\Lib\site-packages (from uvicorn>=0.30.0->streamlit) (0.16.0)
# Note: you may need to restart the kernel to use updated packages.
# 2026-06-21 22:14:10.272 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:14:10.529
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\Ksing\AppData\Roaming\Python\Python314\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2026-06-21 22:14:10.530 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:14:10.531 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:14:10.532 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:14:10.533 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:14:10.534 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:14:10.534 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:14:10.535 Session state does not function when running a script without `streamlit run`
# 2026-06-21 22:14:10.536 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:14:10.536 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:14:10.539 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:14:10.563 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:14:10.573 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:14:10.576 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:14:10.577 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:14:10.578 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:14:10.579 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:14:10.580 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:14:10.581 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:14:10.582 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:14:10.583 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:14:10.584 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:14:10.584 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:14:10.587 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:14:10.588 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:14:10.588 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:14:10.589 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:14:10.589 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:14:10.590 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:14:12.069 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:14:12.069 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:14:12.070 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %% [markdown]
# ## **Case Study 1: Employee Productivity Tracker**
#
# #### **Problem Context**
# A company wants to monitor employee productivity across different departments. The dashboard should:
# 1. Show a table of employees with their department, hours worked, and tasks completed.
# 2. Allow filtering by department.
# 3. Display average hours worked and total tasks completed.
# 4. Show a line chart of hours worked over time.

# %%
import streamlit as st
import pandas as pd
import numpy as np

data = {
    'Employee': [f'Employee {i}' for i in range(1, 21)],
    'Department': ['HR', 'IT', 'Marketing', 'Finance'] * 5,
    'Hours Worked': np.random.randint(30, 50, 20),
    'Tasks Completed': np.random.randint(5, 20, 20)
}
df = pd.DataFrame(data)

# Sidebar Filter
st.sidebar.header("Filters")
department_filter = st.sidebar.selectbox("Select Department", ['All'] + list(df['Department'].unique()))
if department_filter != 'All':
    df = df[df['Department'] == department_filter]

# KPIs
st.title("Employee Productivity Tracker")
st.metric("Average Hours Worked", f"{df['Hours Worked'].mean():.1f} hrs")
st.metric("Total Tasks Completed", df['Tasks Completed'].sum())

# Data Table
st.subheader("Employee Data")
st.dataframe(df)

# Chart
st.subheader("Hours Worked Distribution")
st.line_chart(df[['Employee', 'Hours Worked']].set_index('Employee'))
# Out:
# 2026-06-24 10:04:23.389 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-24 10:04:23.905
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\Ksing\AppData\Roaming\Python\Python314\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2026-06-24 10:04:23.906 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-24 10:04:23.907 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-24 10:04:23.910 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-24 10:04:23.910 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-24 10:04:23.912 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-24 10:04:23.912 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-24 10:04:23.913 Session state does not function when running a script without `streamlit run`
# 2026-06-24 10:04:23.914 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-24 10:04:23.915 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-24 10:04:23.916 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-24 10:04:23.917 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-24 10:04:23.918 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-24 10:04:23.919 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-24 10:04:23.920 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-24 10:04:23.921 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-24 10:04:23.922 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-24 10:04:23.927 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-24 10:04:23.928 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-24 10:04:23.929 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-24 10:04:23.930 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-24 10:04:23.931 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-24 10:04:23.932 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-24 10:04:23.940 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-24 10:04:23.941 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-24 10:04:23.942 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-24 10:04:23.943 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-24 10:04:23.944 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-24 10:04:23.944 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-24 10:04:25.905 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-24 10:04:25.906 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-24 10:04:25.907 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %% [markdown]
# ### **Case Study 2: Sales Dashboard for an E-commerce Store**
# An e-commerce company wants to track its sales performance using an interactive dashboard. The dashboard should allow users to:
# 1. View sales data in a table.
# 2. Filter by product category.
# 3. Create interactive charts
#
# The dataset used in this case study is the Superstore-Sales.xls file, with the following columns:
#
# | Column Name       | Description |
# |------------------|------------|
# | **Order ID**     | Unique identifier for each order. |
# | **Order Date**   | Date when the order was placed. |
# | **Ship Date**    | Date when the order was shipped. |
# | **Ship Mode**    | Shipping type (e.g., Standard, First Class, Same Day). |
# | **Customer ID**  | Unique identifier for each customer. |
# | **Customer Name**| Full name of the customer. |
# | **Segment**      | Market segment (e.g., Consumer, Corporate, Home Office). |
# | **Country**      | Country where the order was placed. |
# | **City**        | City of the customer. |
# | **State**       | State or province. |
# | **Region**      | Geographic region (e.g., East, West, Central). |
# | **Category**    | Product category (e.g., Office Supplies, Technology, Furniture). |
# | **Sub-Category** | More specific product classification (e.g., Chairs, Phones). |
# | **Product ID**  | Unique identifier for each product. |
# | **Product Name** | Name of the purchased product. |
# | **Sales**       | Total revenue generated by the sale. |
# | **Quantity**    | Number of items purchased. |
# | **Discount**    | Discount applied to the order. |
# | **Profit**      | Profit margin after costs. |
#
# This dataset enables analysis of sales trends, profitability, customer segments, and shipping performance.

# %%
# %pip install "xlrd>=2.0.1"
df=pd.read_excel("Sample_Superstore.xls")
df
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting xlrd>=2.0.1
#   Downloading xlrd-2.0.2-py2.py3-none-any.whl.metadata (3.5 kB)
# Downloading xlrd-2.0.2-py2.py3-none-any.whl (96 kB)
# Installing collected packages: xlrd
# Successfully installed xlrd-2.0.2
# Note: you may need to restart the kernel to use updated packages.
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# 1       CG-12520       Claire Gute   Consumer  United States        Henderson
# 2       DV-13045   Darrin Van Huff  Corporate  United States      Los Angeles
# 3       SO-20335    Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 4       SO-20335    Sean O'Donnell   Consumer  United States  Fort Lauderdale
# ...          ...               ...        ...            ...              ...
# 9989    TB-21400  Tom Boeckenhauer   Consumer  United States            Miami
# 9990    DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9991    DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9992    DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9993    CC-12220      Chris Cortes   Consumer  United States      Westminster
#
#       ... Postal Code  Region       Product ID         Category Sub-Category  \
# 0     ...       42420   South  FUR-BO-10001798        Furniture    Bookcases
# 1     ...       42420   South  FUR-CH-10000454        Furniture       Chairs
# 2     ...       90036    West  OFF-LA-10000240  Office Supplies       Labels
# 3     ...       33311   South  FUR-TA-10000577        Furniture       Tables
# 4     ...       33311   South  OFF-ST-10000760  Office Supplies      Storage
# ...   ...         ...     ...              ...              ...          ...
# 9989  ...       33180   South  FUR-FU-10001889        Furniture  Furnishings
# 9990  ...       92627    West  FUR-FU-10000747        Furniture  Furnishings
# 9991  ...       92627    West  TEC-PH-10003645       Technology       Phones
# 9992  ...       92627    West  OFF-PA-10004041  Office Supplies        Paper
# 9993  ...       92683    West  OFF-AP-10002684  Office Supplies   Appliances
#
#                                            Product Name     Sales  Quantity  \
# 0                     Bush Somerset Collection Bookcase  261.9600         2
# 1     Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2     Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3         Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                        Eldon Fold 'N Roll Cart System   22.3680         2
# ...                                                 ...       ...       ...
# 9989                             Ultra Door Pull Handle   25.2480         3
# 9990  Tenex B1-RE Series Chair Mats for Low Pile Car...   91.9600         2
# 9991                              Aastra 57i VoIP phone  258.5760         2
# 9992  It's Hot Message Books with Stickers, 2 3/4" x 5"   29.6000         4
# 9993  Acco 7-Outlet Masterpiece Power Center, Wihtou...  243.1600         2
#
#       Discount    Profit
# 0         0.00   41.9136
# 1         0.00  219.5820
# 2         0.00    6.8714
# 3         0.45 -383.0310
# 4         0.20    2.5164
# ...        ...       ...
# 9989      0.20    4.1028
# 9990      0.00   15.6332
# 9991      0.20   19.3932
# 9992      0.00   13.3200
# 9993      0.00   72.9480
#
# [9994 rows x 21 columns]

# %%
import streamlit as st
import plotly.express as px
import pandas as pd


st.title(" :bar_chart: Sample SuperStore EDA")
df = pd.read_excel("Sample_Superstore.xls")

col1, col2 = st.columns((2))
df["Order Date"] = pd.to_datetime(df["Order Date"])

# Getting the min and max date
startDate = pd.to_datetime(df["Order Date"]).min()
endDate = pd.to_datetime(df["Order Date"]).max()

with col1:
    date1 = pd.to_datetime(st.date_input("Start Date", startDate))

with col2:
    date2 = pd.to_datetime(st.date_input("End Date", endDate))

df = df[(df["Order Date"] >= date1) & (df["Order Date"] <= date2)].copy()

st.sidebar.header("Choose your filter: ")
# Create for Region
region = st.sidebar.multiselect("Pick your Region", df["Region"].unique())
if not region:
    df2 = df.copy()
else:
    df2 = df[df["Region"].isin(region)]

# Create for State
state = st.sidebar.multiselect("Pick the State", df2["State"].unique())
if not state:
    df3 = df2.copy()
else:
    df3 = df2[df2["State"].isin(state)]

# Create for City
city = st.sidebar.multiselect("Pick the City",df3["City"].unique())

# Filter the data based on Region, State and City

if not region and not state and not city:
    filtered_df = df
elif not state and not city:
    filtered_df = df[df["Region"].isin(region)]
elif not region and not city:
    filtered_df = df[df["State"].isin(state)]
elif state and city:
    filtered_df = df3[df["State"].isin(state) & df3["City"].isin(city)]
elif region and city:
    filtered_df = df3[df["Region"].isin(region) & df3["City"].isin(city)]
elif region and state:
    filtered_df = df3[df["Region"].isin(region) & df3["State"].isin(state)]
elif city:
    filtered_df = df3[df3["City"].isin(city)]
else:
    filtered_df = df3[df3["Region"].isin(region) & df3["State"].isin(state) & df3["City"].isin(city)]

category_df = filtered_df.groupby(by = ["Category"], as_index = False)["Sales"].sum()

with col1:
    st.subheader("Category wise Sales")
    fig = px.bar(category_df, x = "Category", y = "Sales", text = ['${:,.2f}'.format(x) for x in category_df["Sales"]],
                 template = "seaborn")
    st.plotly_chart(fig,use_container_width=True, height = 200)

with col2:
    st.subheader("Region wise Sales")
    fig = px.pie(filtered_df, values = "Sales", names = "Region", hole = 0.5)
    fig.update_traces(text = filtered_df["Region"], textposition = "outside")
    st.plotly_chart(fig,use_container_width=True)

cl1, cl2 = st.columns((2))
with cl1:
    with st.expander("Category_ViewData"):
        st.write(category_df.style.background_gradient(cmap="Blues"))
        csv = category_df.to_csv(index = False).encode('utf-8')
        st.download_button("Download Data", data = csv, file_name = "Category.csv", mime = "text/csv",
                            help = 'Click here to download the data as a CSV file')

with cl2:
    with st.expander("Region_ViewData"):
        region = filtered_df.groupby(by = "Region", as_index = False)["Sales"].sum()
        st.write(region.style.background_gradient(cmap="Oranges"))
        csv = region.to_csv(index = False).encode('utf-8')
        st.download_button("Download Data", data = csv, file_name = "Region.csv", mime = "text/csv",
                        help = 'Click here to download the data as a CSV file')

filtered_df["month_year"] = filtered_df["Order Date"].dt.to_period("M")
st.subheader('Time Series Analysis')

linechart = pd.DataFrame(filtered_df.groupby(filtered_df["month_year"].dt.strftime("%Y : %b"))["Sales"].sum()).reset_index()
fig2 = px.line(linechart, x = "month_year", y="Sales", labels = {"Sales": "Amount"},height=500, width = 1000,template="gridon")
st.plotly_chart(fig2,use_container_width=True)

with st.expander("View Data of TimeSeries:"):
    st.write(linechart.T.style.background_gradient(cmap="Blues"))
    csv = linechart.to_csv(index=False).encode("utf-8")
    st.download_button('Download Data', data = csv, file_name = "TimeSeries.csv", mime ='text/csv')


chart1, chart2 = st.columns((2))
with chart1:
    st.subheader('Segment wise Sales')
    fig = px.pie(filtered_df, values = "Sales", names = "Segment", template = "plotly_dark")
    fig.update_traces(text = filtered_df["Segment"], textposition = "inside")
    st.plotly_chart(fig,use_container_width=True)

with chart2:
    st.subheader('Category wise Sales')
    fig = px.pie(filtered_df, values = "Sales", names = "Category", template = "gridon")
    fig.update_traces(text = filtered_df["Category"], textposition = "inside")
    st.plotly_chart(fig,use_container_width=True)
# Out:
# 2026-06-21 22:41:00.349 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:00.350 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:00.351 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:00.698 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:00.699 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:00.699 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:00.730 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:00.730 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:00.731 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:00.731 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:00.732 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:00.733 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:00.734 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:00.734 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:00.735 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:00.736 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:00.737 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:00.738 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:00.744 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:00.745 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:00.746 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:00.747 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:00.748 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:00.749 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:00.751 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:00.751 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:00.752 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:00.754 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:00.755 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:00.757 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:00.757 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:00.758 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:00.759 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:00.760 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:00.761 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:00.762 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:00.764 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:00.764 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:00.765 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:00.769 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:00.771 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:00.772 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:01.020 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-06-21 22:41:01.024 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:01.025 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:01.025 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:01.026 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:01.026 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:01.027 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:01.028 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:01.028 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:01.048 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-06-21 22:41:01.056 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:01.057 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:01.058 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:01.058 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:01.059 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:01.060 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:01.061 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:01.061 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:01.062 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:01.184 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:01.453 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:01.454 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:01.454 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:01.458 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:01.459 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:01.459 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:01.460 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:01.461 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:01.461 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:01.462 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:01.463 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:01.468 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:01.475 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:01.476 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:01.476 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:01.477 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:01.478 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:01.479 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:01.479 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:01.480 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:01.480 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:01.481 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:01.485 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:01.486 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:01.486 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:01.547 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-06-21 22:41:01.548 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:01.549 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:01.549 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:01.550 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:01.550 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:01.552 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:01.554 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:01.580 Serialization of dataframe to Arrow table was unsuccessful. Applying automatic fixes for column types to make the dataframe Arrow-compatible.
# Traceback (most recent call last):
#   File "C:\Users\Ksing\AppData\Roaming\Python\Python314\site-packages\streamlit\dataframe_util.py", line 961, in convert_pandas_df_to_arrow_bytes
#     table = pa.Table.from_pandas(df)
#   File "pyarrow/table.pxi", line 4768, in pyarrow.lib.Table.from_pandas
#   File "C:\Users\Ksing\AppData\Roaming\Python\Python314\site-packages\pyarrow\pandas_compat.py", line 651, in dataframe_to_arrays
#     arrays = [convert_column(c, f)
#               ~~~~~~~~~~~~~~^^^^^^
#   File "C:\Users\Ksing\AppData\Roaming\Python\Python314\site-packages\pyarrow\pandas_compat.py", line 639, in convert_column
#     raise e
#   File "C:\Users\Ksing\AppData\Roaming\Python\Python314\site-packages\pyarrow\pandas_compat.py", line 633, in convert_column
#     result = pa.array(col, type=type_, from_pandas=True, safe=safe)
#   File "pyarrow/array.pxi", line 390, in pyarrow.lib.array
#   File "pyarrow/array.pxi", line 91, in pyarrow.lib._ndarray_to_array
#     check_status(NdarrayToArrow(pool, values, mask, from_pandas,
#   File "pyarrow/error.pxi", line 92, in pyarrow.lib.check_status
# pyarrow.lib.ArrowTypeError: ("Expected bytes, got a 'float' object", 'Conversion failed for column 0 with type object')
# 2026-06-21 22:41:01.626 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:01.626 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:01.627 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:01.629 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:01.630 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:01.630 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:01.631 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:01.631 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:01.632 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:01.633 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:01.634 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:01.635 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:01.636 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:01.637 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:01.638 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:01.638 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:01.675 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-06-21 22:41:01.683 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:01.684 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:01.686 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:01.686 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:01.687 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:01.688 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:01.688 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:01.689 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:01.707 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-06-21 22:41:01.713 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:01.713 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:01.715 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:01.715 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-21 22:41:01.716 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
